# %% [markdown]
# Variáveis: temperatura e quantidade de pessoas em uma praia.

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
f,axarr=plt.subplots(ncols=3)
f.subplots_adjust(right=2)
for i in range(0,3):
    rint=random.randint(15,38,20)
    print(rint)
    x=np.arange(20)
    y=rint
    axarr[i].set_ylim([0,40])
    axarr[i].plot(x,y,'o',color='black',markersize=10);
#print(temps1)
# Out:
# [17 23 23 28 17 21 20 24 29 25 29 28 23 21 16 15 35 37 32 33]
# [23 26 23 21 36 21 31 34 34 28 21 21 20 28 25 34 15 32 21 32]
# [36 19 30 32 36 17 28 34 20 28 28 31 30 27 22 27 37 30 18 20]

# %%
temps1=[17,23,23,28,17,21,20,24,29,25,29,28,23,21,16,15,35,37,32,33]
print(temps1)
# Out:
# [17, 23, 23, 28, 17, 21, 20, 24, 29, 25, 29, 28, 23, 21, 16, 15, 35, 37, 32, 33]
